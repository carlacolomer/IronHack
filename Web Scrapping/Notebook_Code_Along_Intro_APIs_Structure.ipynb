# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '17993595718',
#   'type': 'PushEvent',
#   'actor': {'id': 43733305,
#    'login': 'yanonono',
#    'display_login': 'yanonono',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yanonono',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43733305?'},
#   'repo': {'id': 183440182,
#    'name': 'yanonono/booth-update',
#    'url': 'https://api.github.com/repos/yanonono/booth-update'},
#   'payload': {'push_id': 7938246757,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2d458ad16a958ce354be64ea8a8a91318d35b157',
#    'before': '1a7c603995fe624a31bf30db503e561661ee2178',
#    'commits': [{'sha': '2d458ad16a958ce354be64ea8a8a91318d35b157',
#      'author': {'email': 'yano.nono.0701+booth-github@gmail.com',
#       'name': 'yano.nono'},
#      'message': 'updated at: 2021-09-15 18:14, VRchat向けアクセサリー\u3000ぷちどらごん - chemical&#39;s shop - BOOTH',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yanonono/booth-update/commits/2d458ad16a958ce354be64ea8a8a91318d35b157'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595682',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 172341180,
#    'name': 'lacolaco/contributors-img',
#    'url': 'https://api.github.com/repos/lacolaco/contributors-img'},
#   'payload': {'action': 'opened',
#    'number': 859,
#    'pull_request': {'url': 'https://api.github.com/repos/lacolaco/contributors-img/pulls/859',
#     'id': 734374275,
#     'node_id': 'PR_kwDOCkW3vM4rxamD',
#     'html_url': 'https://github.com/lacolaco/contributors-img/pull/859',
#     'diff_url': 'https://github.com/lacolaco/contributors-img/pull/859.diff',
#     'patch_url': 'https://github.com/lacolaco/contributors-img/pull/859.patch',
#     'issue_url': 'https://api.github.com/repos/lacolaco/contributors-img/issues/859',
#     'number': 859,
#     'state': 'open',
#     'locked': False,
#     'title': 'release',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Preview: ![](https://stg.contrib.rocks/image?repo=angular/angular-ja)',
#     'created_at': '2021-09-15T09:14:32Z',
#     'updated_at': '2021-09-15T09:14:32Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/lacolaco/contributors-img/pulls/859/commits',
#     'review_comments_url': 'https://api.github.com/repos/lacolaco/contributors-img/pulls/859/comments',
#     'review_comment_url': 'https://api.github.com/repos/lacolaco/contributors-img/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/lacolaco/contributors-img/issues/859/comments',
#     'statuses_url': 'https://api.github.com/repos/lacolaco/contributors-img/statuses/1810992cb0a786f84cf536a3de0b4815ed3ccc18',
#     'head': {'label': 'lacolaco:main',
#      'ref': 'main',
#      'sha': '1810992cb0a786f84cf536a3de0b4815ed3ccc18',
#      'user': {'login': 'lacolaco',
#       'id': 1529180,
#       'node_id': 'MDQ6VXNlcjE1MjkxODA=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1529180?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/lacolaco',
#       'html_url': 'https://github.com/lacolaco',
#       'followers_url': 'https://api.github.com/users/lacolaco/followers',
#       'following_url': 'https://api.github.com/users/lacolaco/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/lacolaco/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/lacolaco/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/lacolaco/subscriptions',
#       'organizations_url': 'https://api.github.com/users/lacolaco/orgs',
#       'repos_url': 'https://api.github.com/users/lacolaco/repos',
#       'events_url': 'https://api.github.com/users/lacolaco/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/lacolaco/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 172341180,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzIzNDExODA=',
#       'name': 'contributors-img',
#       'full_name': 'lacolaco/contributors-img',
#       'private': False,
#       'owner': {'login': 'lacolaco',
#        'id': 1529180,
#        'node_id': 'MDQ6VXNlcjE1MjkxODA=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1529180?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/lacolaco',
#        'html_url': 'https://github.com/lacolaco',
#        'followers_url': 'https://api.github.com/users/lacolaco/followers',
#        'following_url': 'https://api.github.com/users/lacolaco/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/lacolaco/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/lacolaco/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/lacolaco/subscriptions',
#        'organizations_url': 'https://api.github.com/users/lacolaco/orgs',
#        'repos_url': 'https://api.github.com/users/lacolaco/repos',
#        'events_url': 'https://api.github.com/users/lacolaco/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/lacolaco/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/lacolaco/contributors-img',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/lacolaco/contributors-img',
#       'forks_url': 'https://api.github.com/repos/lacolaco/contributors-img/forks',
#       'keys_url': 'https://api.github.com/repos/lacolaco/contributors-img/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/lacolaco/contributors-img/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/lacolaco/contributors-img/teams',
#       'hooks_url': 'https://api.github.com/repos/lacolaco/contributors-img/hooks',
#       'issue_events_url': 'https://api.github.com/repos/lacolaco/contributors-img/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/lacolaco/contributors-img/events',
#       'assignees_url': 'https://api.github.com/repos/lacolaco/contributors-img/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/lacolaco/contributors-img/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/lacolaco/contributors-img/tags',
#       'blobs_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/lacolaco/contributors-img/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/lacolaco/contributors-img/languages',
#       'stargazers_url': 'https://api.github.com/repos/lacolaco/contributors-img/stargazers',
#       'contributors_url': 'https://api.github.com/repos/lacolaco/contributors-img/contributors',
#       'subscribers_url': 'https://api.github.com/repos/lacolaco/contributors-img/subscribers',
#       'subscription_url': 'https://api.github.com/repos/lacolaco/contributors-img/subscription',
#       'commits_url': 'https://api.github.com/repos/lacolaco/contributors-img/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/lacolaco/contributors-img/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/lacolaco/contributors-img/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/lacolaco/contributors-img/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/lacolaco/contributors-img/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/lacolaco/contributors-img/merges',
#       'archive_url': 'https://api.github.com/repos/lacolaco/contributors-img/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/lacolaco/contributors-img/downloads',
#       'issues_url': 'https://api.github.com/repos/lacolaco/contributors-img/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/lacolaco/contributors-img/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/lacolaco/contributors-img/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/lacolaco/contributors-img/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/lacolaco/contributors-img/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/lacolaco/contributors-img/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/lacolaco/contributors-img/deployments',
#       'created_at': '2019-02-24T13:31:21Z',
#       'updated_at': '2021-09-15T09:14:06Z',
#       'pushed_at': '2021-09-15T09:14:03Z',
#       'git_url': 'git://github.com/lacolaco/contributors-img.git',
#       'ssh_url': 'git@github.com:lacolaco/contributors-img.git',
#       'clone_url': 'https://github.com/lacolaco/contributors-img.git',
#       'svn_url': 'https://github.com/lacolaco/contributors-img',
#       'homepage': 'https://contrib.rocks',
#       'size': 11761,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': None,
#       'allow_forking': True,
#       'forks': 1,
#       'open_issues': 12,
#       'watchers': 6,
#       'default_branch': 'main'}},
#     'base': {'label': 'lacolaco:production',
#      'ref': 'production',
#      'sha': '62b73e23be381a6cc041a697cb73bf53fcbae6a6',
#      'user': {'login': 'lacolaco',
#       'id': 1529180,
#       'node_id': 'MDQ6VXNlcjE1MjkxODA=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1529180?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/lacolaco',
#       'html_url': 'https://github.com/lacolaco',
#       'followers_url': 'https://api.github.com/users/lacolaco/followers',
#       'following_url': 'https://api.github.com/users/lacolaco/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/lacolaco/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/lacolaco/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/lacolaco/subscriptions',
#       'organizations_url': 'https://api.github.com/users/lacolaco/orgs',
#       'repos_url': 'https://api.github.com/users/lacolaco/repos',
#       'events_url': 'https://api.github.com/users/lacolaco/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/lacolaco/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 172341180,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzIzNDExODA=',
#       'name': 'contributors-img',
#       'full_name': 'lacolaco/contributors-img',
#       'private': False,
#       'owner': {'login': 'lacolaco',
#        'id': 1529180,
#        'node_id': 'MDQ6VXNlcjE1MjkxODA=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1529180?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/lacolaco',
#        'html_url': 'https://github.com/lacolaco',
#        'followers_url': 'https://api.github.com/users/lacolaco/followers',
#        'following_url': 'https://api.github.com/users/lacolaco/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/lacolaco/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/lacolaco/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/lacolaco/subscriptions',
#        'organizations_url': 'https://api.github.com/users/lacolaco/orgs',
#        'repos_url': 'https://api.github.com/users/lacolaco/repos',
#        'events_url': 'https://api.github.com/users/lacolaco/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/lacolaco/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/lacolaco/contributors-img',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/lacolaco/contributors-img',
#       'forks_url': 'https://api.github.com/repos/lacolaco/contributors-img/forks',
#       'keys_url': 'https://api.github.com/repos/lacolaco/contributors-img/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/lacolaco/contributors-img/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/lacolaco/contributors-img/teams',
#       'hooks_url': 'https://api.github.com/repos/lacolaco/contributors-img/hooks',
#       'issue_events_url': 'https://api.github.com/repos/lacolaco/contributors-img/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/lacolaco/contributors-img/events',
#       'assignees_url': 'https://api.github.com/repos/lacolaco/contributors-img/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/lacolaco/contributors-img/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/lacolaco/contributors-img/tags',
#       'blobs_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/lacolaco/contributors-img/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/lacolaco/contributors-img/languages',
#       'stargazers_url': 'https://api.github.com/repos/lacolaco/contributors-img/stargazers',
#       'contributors_url': 'https://api.github.com/repos/lacolaco/contributors-img/contributors',
#       'subscribers_url': 'https://api.github.com/repos/lacolaco/contributors-img/subscribers',
#       'subscription_url': 'https://api.github.com/repos/lacolaco/contributors-img/subscription',
#       'commits_url': 'https://api.github.com/repos/lacolaco/contributors-img/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/lacolaco/contributors-img/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/lacolaco/contributors-img/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/lacolaco/contributors-img/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/lacolaco/contributors-img/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/lacolaco/contributors-img/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/lacolaco/contributors-img/merges',
#       'archive_url': 'https://api.github.com/repos/lacolaco/contributors-img/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/lacolaco/contributors-img/downloads',
#       'issues_url': 'https://api.github.com/repos/lacolaco/contributors-img/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/lacolaco/contributors-img/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/lacolaco/contributors-img/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/lacolaco/contributors-img/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/lacolaco/contributors-img/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/lacolaco/contributors-img/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/lacolaco/contributors-img/deployments',
#       'created_at': '2019-02-24T13:31:21Z',
#       'updated_at': '2021-09-15T09:14:06Z',
#       'pushed_at': '2021-09-15T09:14:03Z',
#       'git_url': 'git://github.com/lacolaco/contributors-img.git',
#       'ssh_url': 'git@github.com:lacolaco/contributors-img.git',
#       'clone_url': 'https://github.com/lacolaco/contributors-img.git',
#       'svn_url': 'https://github.com/lacolaco/contributors-img',
#       'homepage': 'https://contrib.rocks',
#       'size': 11761,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': None,
#       'allow_forking': True,
#       'forks': 1,
#       'open_issues': 12,
#       'watchers': 6,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/lacolaco/contributors-img/pulls/859'},
#      'html': {'href': 'https://github.com/lacolaco/contributors-img/pull/859'},
#      'issue': {'href': 'https://api.github.com/repos/lacolaco/contributors-img/issues/859'},
#      'comments': {'href': 'https://api.github.com/repos/lacolaco/contributors-img/issues/859/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/lacolaco/contributors-img/pulls/859/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/lacolaco/contributors-img/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/lacolaco/contributors-img/pulls/859/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/lacolaco/contributors-img/statuses/1810992cb0a786f84cf536a3de0b4815ed3ccc18'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 184,
#     'deletions': 100,
#     'changed_files': 9}},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595703',
#   'type': 'PushEvent',
#   'actor': {'id': 7920370,
#    'login': 'dreamerminsk',
#    'display_login': 'dreamerminsk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dreamerminsk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7920370?'},
#   'repo': {'id': 401275574,
#    'name': 'dreamerminsk/gowiki',
#    'url': 'https://api.github.com/repos/dreamerminsk/gowiki'},
#   'payload': {'push_id': 7938246778,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b2d41dd0c5f9d16d15fc3370e5ea471fed3fa5e6',
#    'before': 'f3aad6ef28c3689524404febac5c9cb89e432a52',
#    'commits': [{'sha': '90b99b5dcbc736cc8ef0520413f170fb74d7d8c4',
#      'author': {'email': 'tutmirage@gmail.com', 'name': 'Micah Teeuws'},
#      'message': 'type Storage interface',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/dreamerminsk/gowiki/commits/90b99b5dcbc736cc8ef0520413f170fb74d7d8c4'},
#     {'sha': '3a83e03a592f3ca4c50a8e3f4c8043277438ffcc',
#      'author': {'email': 'tutmirage@gmail.com', 'name': 'Micah Teeuws'},
#      'message': 'lock *sync.Mutex',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/dreamerminsk/gowiki/commits/3a83e03a592f3ca4c50a8e3f4c8043277438ffcc'},
#     {'sha': 'b2d41dd0c5f9d16d15fc3370e5ea471fed3fa5e6',
#      'author': {'email': 'tutmirage@gmail.com', 'name': 'Micah Teeuws'},
#      'message': 'Merge pull request #6 from dreamerminsk/singleton\n\nSingleton',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dreamerminsk/gowiki/commits/b2d41dd0c5f9d16d15fc3370e5ea471fed3fa5e6'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595694',
#   'type': 'PushEvent',
#   'actor': {'id': 64201251,
#    'login': 'tachibanatanaka',
#    'display_login': 'tachibanatanaka',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tachibanatanaka',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64201251?'},
#   'repo': {'id': 406691023,
#    'name': 'tachibanatanaka/Jake-Todo',
#    'url': 'https://api.github.com/repos/tachibanatanaka/Jake-Todo'},
#   'payload': {'push_id': 7938246753,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fe226eba471fd20322239380c81a18107cbd2f08',
#    'before': '172ba9633184cce33b5159a6075a2e13258c23e2',
#    'commits': [{'sha': 'fe226eba471fd20322239380c81a18107cbd2f08',
#      'author': {'email': '64201251+tachibanatanaka@users.noreply.github.com',
#       'name': 'tachibanatanaka'},
#      'message': 'Set theme jekyll-theme-slate',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tachibanatanaka/Jake-Todo/commits/fe226eba471fd20322239380c81a18107cbd2f08'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595697',
#   'type': 'PushEvent',
#   'actor': {'id': 18388400,
#    'login': 'Rackar',
#    'display_login': 'Rackar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rackar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18388400?'},
#   'repo': {'id': 402367765,
#    'name': 'Rackar/powerTools',
#    'url': 'https://api.github.com/repos/Rackar/powerTools'},
#   'payload': {'push_id': 7938246765,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a94650e81c0d8aaab8302ed6ad663874578de8b6',
#    'before': '19573927d085c51e686e2a6ba6b12bbeccef62fe',
#    'commits': [{'sha': 'a94650e81c0d8aaab8302ed6ad663874578de8b6',
#      'author': {'email': '27681135@qq.com', 'name': 'Rackar'},
#      'message': '修改Yxml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Rackar/powerTools/commits/a94650e81c0d8aaab8302ed6ad663874578de8b6'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595690',
#   'type': 'PushEvent',
#   'actor': {'id': 27745384,
#    'login': 'waiizen',
#    'display_login': 'waiizen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/waiizen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27745384?'},
#   'repo': {'id': 405980972,
#    'name': 'waiizen/QuestionnairePractitioner',
#    'url': 'https://api.github.com/repos/waiizen/QuestionnairePractitioner'},
#   'payload': {'push_id': 7938246770,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '87a9394f3917997c477b221509aff257b2a4972f',
#    'before': 'f2d5c1ece4a32391832588805182591afcb08e64',
#    'commits': [{'sha': '87a9394f3917997c477b221509aff257b2a4972f',
#      'author': {'email': 'nathanferrer.nf@gmail.com', 'name': 'Nathan'},
#      'message': 'fix: Nouveau questionnaire',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/waiizen/QuestionnairePractitioner/commits/87a9394f3917997c477b221509aff257b2a4972f'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595676',
#   'type': 'PushEvent',
#   'actor': {'id': 32444997,
#    'login': 'huymach91',
#    'display_login': 'huymach91',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/huymach91',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32444997?'},
#   'repo': {'id': 396354169,
#    'name': 'huymach91/hm-angular-virtual-scroller',
#    'url': 'https://api.github.com/repos/huymach91/hm-angular-virtual-scroller'},
#   'payload': {'push_id': 7938246752,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '85bf56ea36dcc06205e3f7bed06f5793a353b627',
#    'before': 'e2878d30c5d52802f17baae63896ebd933aebf8f',
#    'commits': [{'sha': 'c21f3e6df2a0286e996140081a5034ba20f3fa92',
#      'author': {'email': 'huy.mach.webdev@gmail.com', 'name': 'huymach91'},
#      'message': '4 files modified',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/huymach91/hm-angular-virtual-scroller/commits/c21f3e6df2a0286e996140081a5034ba20f3fa92'},
#     {'sha': '85bf56ea36dcc06205e3f7bed06f5793a353b627',
#      'author': {'email': 'huy.mach.webdev@gmail.com', 'name': 'huymach91'},
#      'message': '4 files modified',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/huymach91/hm-angular-virtual-scroller/commits/85bf56ea36dcc06205e3f7bed06f5793a353b627'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595664',
#   'type': 'IssuesEvent',
#   'actor': {'id': 24226825,
#    'login': 'noliveleger',
#    'display_login': 'noliveleger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/noliveleger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24226825?'},
#   'repo': {'id': 50376388,
#    'name': 'kobotoolbox/formpack',
#    'url': 'https://api.github.com/repos/kobotoolbox/formpack'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/kobotoolbox/formpack/issues/47',
#     'repository_url': 'https://api.github.com/repos/kobotoolbox/formpack',
#     'labels_url': 'https://api.github.com/repos/kobotoolbox/formpack/issues/47/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kobotoolbox/formpack/issues/47/comments',
#     'events_url': 'https://api.github.com/repos/kobotoolbox/formpack/issues/47/events',
#     'html_url': 'https://github.com/kobotoolbox/formpack/issues/47',
#     'id': 144736277,
#     'node_id': 'MDU6SXNzdWUxNDQ3MzYyNzc=',
#     'number': 47,
#     'title': 'Include URL of media attachments in exports',
#     'user': {'login': 'tinok',
#      'id': 673511,
#      'node_id': 'MDQ6VXNlcjY3MzUxMQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/673511?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tinok',
#      'html_url': 'https://github.com/tinok',
#      'followers_url': 'https://api.github.com/users/tinok/followers',
#      'following_url': 'https://api.github.com/users/tinok/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tinok/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tinok/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tinok/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tinok/orgs',
#      'repos_url': 'https://api.github.com/users/tinok/repos',
#      'events_url': 'https://api.github.com/users/tinok/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tinok/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 316488095,
#       'node_id': 'MDU6TGFiZWwzMTY0ODgwOTU=',
#       'url': 'https://api.github.com/repos/kobotoolbox/formpack/labels/enhancement',
#       'name': 'enhancement',
#       'color': '84b6eb',
#       'default': True,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'joshuaberetta',
#      'id': 50016008,
#      'node_id': 'MDQ6VXNlcjUwMDE2MDA4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/50016008?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/joshuaberetta',
#      'html_url': 'https://github.com/joshuaberetta',
#      'followers_url': 'https://api.github.com/users/joshuaberetta/followers',
#      'following_url': 'https://api.github.com/users/joshuaberetta/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/joshuaberetta/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/joshuaberetta/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/joshuaberetta/subscriptions',
#      'organizations_url': 'https://api.github.com/users/joshuaberetta/orgs',
#      'repos_url': 'https://api.github.com/users/joshuaberetta/repos',
#      'events_url': 'https://api.github.com/users/joshuaberetta/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/joshuaberetta/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'joshuaberetta',
#       'id': 50016008,
#       'node_id': 'MDQ6VXNlcjUwMDE2MDA4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/50016008?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/joshuaberetta',
#       'html_url': 'https://github.com/joshuaberetta',
#       'followers_url': 'https://api.github.com/users/joshuaberetta/followers',
#       'following_url': 'https://api.github.com/users/joshuaberetta/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/joshuaberetta/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/joshuaberetta/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/joshuaberetta/subscriptions',
#       'organizations_url': 'https://api.github.com/users/joshuaberetta/orgs',
#       'repos_url': 'https://api.github.com/users/joshuaberetta/repos',
#       'events_url': 'https://api.github.com/users/joshuaberetta/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/joshuaberetta/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 11,
#     'created_at': '2016-03-30T22:17:07Z',
#     'updated_at': '2021-09-15T09:14:31Z',
#     'closed_at': '2021-09-15T09:14:31Z',
#     'author_association': 'MEMBER',
#     'active_lock_reason': None,
#     'body': 'For each attachment (video, image, recording, audit.csv, etc.) that was sent with a submission, include the URL to the file in an additional column named `[original_question_name]_URL`.\r\n\r\nFor example\r\n\r\n|name|image|image_URL|\r\n|--|--|--|\r\n|tino|someimage.jpg|https://kc.kobotoolbox.org/media/original?media_file=tinokreutzer/attachments/45c70e9b2cdc44b8b047cfd135542e56/41a86b06-4d1c-4c5c-8b4e-2cf019d30a83/someimage.jpg|\r\n\r\nRelated to #43 and #46',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z',
#   'org': {'id': 5543677,
#    'login': 'kobotoolbox',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kobotoolbox',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5543677?'}},
#  {'id': '17993595675',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 377837702,
#    'name': 'bbeesley/build-test-merge-publish',
#    'url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish/issues/185',
#     'repository_url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish',
#     'labels_url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish/issues/185/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish/issues/185/comments',
#     'events_url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish/issues/185/events',
#     'html_url': 'https://github.com/bbeesley/build-test-merge-publish/pull/185',
#     'id': 995792390,
#     'node_id': 'PR_kwDOFoVYhs4ruBUs',
#     'number': 185,
#     'title': 'chore(deps-dev): bump @octokit/graphql-schema from 10.69.1 to 10.70.0',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 3095695655,
#       'node_id': 'MDU6TGFiZWwzMDk1Njk1NjU1',
#       'url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2021-09-14T09:22:18Z',
#     'updated_at': '2021-09-15T09:14:32Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish/pulls/185',
#      'html_url': 'https://github.com/bbeesley/build-test-merge-publish/pull/185',
#      'diff_url': 'https://github.com/bbeesley/build-test-merge-publish/pull/185.diff',
#      'patch_url': 'https://github.com/bbeesley/build-test-merge-publish/pull/185.patch'},
#     'body': 'Bumps [@octokit/graphql-schema](https://github.com/octokit/graphql-schema) from 10.69.1 to 10.70.0.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/octokit/graphql-schema/releases"><code>@\u200boctokit/graphql-schema</code>\'s releases</a>.</em></p>\n<blockquote>\n<h2>v10.70.0</h2>\n<h1><a href="https://github.com/octokit/graphql-schema/compare/v10.69.1...v10.70.0">10.70.0</a> (2021-09-13)</h1>\n<h3>Features</h3>\n<ul>\n<li><code>Repository#forkingAllowed</code> (<a href="https://github-redirect.dependabot.com/octokit/graphql-schema/issues/552">#552</a>) (<a href="https://github.com/octokit/graphql-schema/commit/a99aa4c378d893950ade69e06b68300bd81502e0">a99aa4c</a>)</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/octokit/graphql-schema/commit/a99aa4c378d893950ade69e06b68300bd81502e0"><code>a99aa4c</code></a> feat: <code>Repository#forkingAllowed</code> (<a href="https://github-redirect.dependabot.com/octokit/graphql-schema/issues/552">#552</a>)</li>\n<li><a href="https://github.com/octokit/graphql-schema/commit/a72441ffde9c3197b2651577f5c8efe18dda2d6c"><code>a72441f</code></a> build(deps): lock file maintenance</li>\n<li><a href="https://github.com/octokit/graphql-schema/commit/14b4eab3cbf25c461442b31ded2c095dfaa98706"><code>14b4eab</code></a> build: description updates (<a href="https://github-redirect.dependabot.com/octokit/graphql-schema/issues/550">#550</a>)</li>\n<li>See full diff in <a href="https://github.com/octokit/graphql-schema/compare/v10.69.1...v10.70.0">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=@octokit/graphql-schema&package-manager=npm_and_yarn&previous-version=10.69.1&new-version=10.70.0)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n\n\n</details>',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish/issues/comments/919844982',
#     'html_url': 'https://github.com/bbeesley/build-test-merge-publish/pull/185#issuecomment-919844982',
#     'issue_url': 'https://api.github.com/repos/bbeesley/build-test-merge-publish/issues/185',
#     'id': 919844982,
#     'node_id': 'IC_kwDOFoVYhs4207h2',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-09-15T09:14:32Z',
#     'updated_at': '2021-09-15T09:14:32Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Superseded by #186.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595667',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 495403,
#    'login': 'reidhoch',
#    'display_login': 'reidhoch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/reidhoch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/495403?'},
#   'repo': {'id': 371758553,
#    'name': 'reidhoch/oeis-seq',
#    'url': 'https://api.github.com/repos/reidhoch/oeis-seq'},
#   'payload': {'action': 'closed',
#    'number': 53,
#    'pull_request': {'url': 'https://api.github.com/repos/reidhoch/oeis-seq/pulls/53',
#     'id': 732850161,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NzMyODUwMTYx',
#     'html_url': 'https://github.com/reidhoch/oeis-seq/pull/53',
#     'diff_url': 'https://github.com/reidhoch/oeis-seq/pull/53.diff',
#     'patch_url': 'https://github.com/reidhoch/oeis-seq/pull/53.patch',
#     'issue_url': 'https://api.github.com/repos/reidhoch/oeis-seq/issues/53',
#     'number': 53,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump hypothesis from 6.20.1 to 6.21.1',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [hypothesis](https://github.com/HypothesisWorks/hypothesis) from 6.20.1 to 6.21.1.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/HypothesisWorks/hypothesis/releases">hypothesis\'s releases</a>.</em></p>\n<blockquote>\n<h2>Hypothesis for Python - version 6.21.1</h2>\n<p>This release improves the behaviour of &quot;builds()&quot; and &quot;from_type()&quot; in\ncertain situations involving decorators (issue <a href="https://github-redirect.dependabot.com/HypothesisWorks/hypothesis/issues/2495">#2495</a> and issue <a href="https://github-redirect.dependabot.com/HypothesisWorks/hypothesis/issues/3029">#3029</a>).</p>\n<p><em><a href="https://hypothesis.readthedocs.io/en/latest/changes.html#v6-21-1">The canonical version of these notes (with links) is on readthedocs.</a></em></p>\n<h2>Hypothesis for Python - version 6.21.0</h2>\n<p>This release introduces strategies for array/tensor libraries adopting\nthe Array API standard (issue <a href="https://github-redirect.dependabot.com/HypothesisWorks/hypothesis/issues/3037">#3037</a>). They are available in the\nhypothesis.extra.array_api extra, and work much like the existing\nstrategies for NumPy.</p>\n<p><em><a href="https://hypothesis.readthedocs.io/en/latest/changes.html#v6-21-0">The canonical version of these notes (with links) is on readthedocs.</a></em></p>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/41fadf9ccfaa04dbc1054af3ee0ab675a90377b8"><code>41fadf9</code></a> Bump hypothesis-python version to 6.21.1 and update changelog</li>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/9f5b30058c5c7454e932dc144dce7588611464c2"><code>9f5b300</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/HypothesisWorks/hypothesis/issues/3095">#3095</a> from Zac-HD/signature-upgrade</li>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/7f2bffc0a469a6445dc56710c96436e8687a542d"><code>7f2bffc</code></a> Fix string formatting</li>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/0d541d5205a0d2abe3449ac1fd826a55ca28dd84"><code>0d541d5</code></a> Better get_lambda_source</li>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/d6db0de01ef1c5a868553e2bc88838bdee98b77f"><code>d6db0de</code></a> Refactor proxies</li>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/4c222b8b75fcec7a53c33c7a5b062ae9b5b73039"><code>4c222b8</code></a> unbind_method is unused</li>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/4fb53a2893164c234f065b09856f4ea325ad9073"><code>4fb53a2</code></a> Required args via signature()</li>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/73c2d2265f13bb1323f72087774ac922198bb375"><code>73c2d22</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/HypothesisWorks/hypothesis/issues/3093">#3093</a> from HypothesisWorks/create-pull-request/patch</li>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/77c0a6437c0d74e4d03dd7f2a694a21a93babeea"><code>77c0a64</code></a> Update pinned dependencies</li>\n<li><a href="https://github.com/HypothesisWorks/hypothesis/commit/3761dc703e86971d6440d2e31fa37b9c7888ae6c"><code>3761dc7</code></a> Bump hypothesis-python version to 6.21.0 and update changelog</li>\n<li>Additional commits viewable in <a href="https://github.com/HypothesisWorks/hypothesis/compare/hypothesis-python-6.20.1...hypothesis-python-6.21.1">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=hypothesis&package-manager=pip&previous-version=6.20.1&new-version=6.21.1)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conf ...
#     'created_at': '2021-09-13T15:13:18Z',
#     'updated_at': '2021-09-15T09:14:32Z',
#     'closed_at': '2021-09-15T09:14:32Z',
#     'merged_at': '2021-09-15T09:14:31Z',
#     'merge_commit_sha': '7f27ac6e96337980dd70b99d418888ab6563687d',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 3075488060,
#       'node_id': 'MDU6TGFiZWwzMDc1NDg4MDYw',
#       'url': 'https://api.github.com/repos/reidhoch/oeis-seq/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/reidhoch/oeis-seq/pulls/53/commits',
#     'review_comments_url': 'https://api.github.com/repos/reidhoch/oeis-seq/pulls/53/comments',
#     'review_comment_url': 'https://api.github.com/repos/reidhoch/oeis-seq/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/reidhoch/oeis-seq/issues/53/comments',
#     'statuses_url': 'https://api.github.com/repos/reidhoch/oeis-seq/statuses/18a0dcc8a49dc16eb835dc58ed119b2d688d0ce6',
#     'head': {'label': 'reidhoch:dependabot/pip/develop/hypothesis-6.21.1',
#      'ref': 'dependabot/pip/develop/hypothesis-6.21.1',
#      'sha': '18a0dcc8a49dc16eb835dc58ed119b2d688d0ce6',
#      'user': {'login': 'reidhoch',
#       'id': 495403,
#       'node_id': 'MDQ6VXNlcjQ5NTQwMw==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/495403?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/reidhoch',
# ...
#       'languages_url': 'https://api.github.com/repos/integritee-network/worker/languages',
#       'stargazers_url': 'https://api.github.com/repos/integritee-network/worker/stargazers',
#       'contributors_url': 'https://api.github.com/repos/integritee-network/worker/contributors',
#       'subscribers_url': 'https://api.github.com/repos/integritee-network/worker/subscribers',
#       'subscription_url': 'https://api.github.com/repos/integritee-network/worker/subscription',
#       'commits_url': 'https://api.github.com/repos/integritee-network/worker/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/integritee-network/worker/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/integritee-network/worker/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/integritee-network/worker/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/integritee-network/worker/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/integritee-network/worker/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/integritee-network/worker/merges',
#       'archive_url': 'https://api.github.com/repos/integritee-network/worker/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/integritee-network/worker/downloads',
#       'issues_url': 'https://api.github.com/repos/integritee-network/worker/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/integritee-network/worker/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/integritee-network/worker/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/integritee-network/worker/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/integritee-network/worker/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/integritee-network/worker/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/integritee-network/worker/deployments',
#       'created_at': '2019-04-16T11:53:45Z',
#       'updated_at': '2021-09-15T07:34:44Z',
#       'pushed_at': '2021-09-15T07:27:25Z',
#       'git_url': 'git://github.com/integritee-network/worker.git',
#       'ssh_url': 'git@github.com:integritee-network/worker.git',
#       'clone_url': 'https://github.com/integritee-network/worker.git',
#       'svn_url': 'https://github.com/integritee-network/worker',
#       'homepage': None,
#       'size': 3732,
#       'stargazers_count': 30,
#       'watchers_count': 30,
#       'language': 'Rust',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 18,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 81,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'forks': 18,
#       'open_issues': 81,
#       'watchers': 30,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/integritee-network/worker/pulls/402'},
#      'html': {'href': 'https://github.com/integritee-network/worker/pull/402'},
#      'issue': {'href': 'https://api.github.com/repos/integritee-network/worker/issues/402'},
#      'comments': {'href': 'https://api.github.com/repos/integritee-network/worker/issues/402/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/integritee-network/worker/pulls/402/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/integritee-network/worker/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/integritee-network/worker/pulls/402/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/integritee-network/worker/statuses/324dcbcf0ce9b2f3aadf391994091cdcabdd66db'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z',
#   'org': {'id': 86358325,
#    'login': 'integritee-network',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/integritee-network',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86358325?'}},
#  {'id': '17993595553',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 13595212,
#    'name': 'pubstandards/pubstandards-london',
#    'url': 'https://api.github.com/repos/pubstandards/pubstandards-london'},
#   'payload': {'push_id': 7938246724,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'e741e895ffa0468c0e1dc093d0334c606d8b77ed',
#    'before': 'fd8df03bfe7793e1fb4a4ea43cefe740fbb70dbf',
#    'commits': [{'sha': 'e741e895ffa0468c0e1dc093d0334c606d8b77ed',
#      'author': {'email': 'jonty@jonty.co.uk', 'name': 'pubstandards-london'},
#      'message': 'Deploying to gh-pages from  @ e368818a2703a5d696ae414b317a15fb94ba5fe4 🚀',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pubstandards/pubstandards-london/commits/e741e895ffa0468c0e1dc093d0334c606d8b77ed'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z',
#   'org': {'id': 7117218,
#    'login': 'pubstandards',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pubstandards',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7117218?'}},
#  {'id': '17993595531',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 314087409,
#    'name': 'b0kch01/b0kch01',
#    'url': 'https://api.github.com/repos/b0kch01/b0kch01'},
#   'payload': {'push_id': 7938246681,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '271a7edbbf9e8e6ae49bccc31988740762baf0a0',
#    'before': 'd76c789671b112639c665e8f322fb5728e30a856',
#    'commits': [{'sha': '271a7edbbf9e8e6ae49bccc31988740762baf0a0',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update github-metrics.svg - [Skip GitHub Action]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/b0kch01/b0kch01/commits/271a7edbbf9e8e6ae49bccc31988740762baf0a0'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595549',
#   'type': 'PushEvent',
#   'actor': {'id': 89893383,
#    'login': 'beom24685',
#    'display_login': 'beom24685',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/beom24685',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89893383?'},
#   'repo': {'id': 401928750,
#    'name': 'beom24685/beom24685.github.io',
#    'url': 'https://api.github.com/repos/beom24685/beom24685.github.io'},
#   'payload': {'push_id': 7938246729,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0a3812d59e3cd4a594cd51a546c1246c72eeb3c2',
#    'before': '1f4fda2f2d970902f4368f2ed6dde9ed2a2caa51',
#    'commits': [{'sha': '0a3812d59e3cd4a594cd51a546c1246c72eeb3c2',
#      'author': {'email': '89893383+beom24685@users.noreply.github.com',
#       'name': 'beom24685'},
#      'message': 'Update 210915x3.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/beom24685/beom24685.github.io/commits/0a3812d59e3cd4a594cd51a546c1246c72eeb3c2'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595543',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 86929735,
#    'name': 'Lombiq/Orchard',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard'},
#   'payload': {'push_id': 7938246710,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/MatteoPiovanelli-Laser-patch-2',
#    'head': 'fc4aca0a29fc5364c02969d4d6b33c9d9ea8a044',
#    'before': 'fc4aca0a29fc5364c02969d4d6b33c9d9ea8a044',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '17993595558',
#   'type': 'PushEvent',
#   'actor': {'id': 6679870,
#    'login': 'suzutan',
#    'display_login': 'suzutan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/suzutan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6679870?'},
#   'repo': {'id': 318534348,
#    'name': 'patioglass/adjustimer',
#    'url': 'https://api.github.com/repos/patioglass/adjustimer'},
#   'payload': {'push_id': 7938246702,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ci',
#    'head': 'b800135515fa8dfe01ee67c13a41cf4ea65c5098',
#    'before': 'c2e561aa81f1dde10c89d3792b1d2455ad546120',
#    'commits': [{'sha': 'b800135515fa8dfe01ee67c13a41cf4ea65c5098',
#      'author': {'email': 'admin@suzutan.jp', 'name': 'Suzuka Asagiri'},
#      'message': 'add pr job(test)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/patioglass/adjustimer/commits/b800135515fa8dfe01ee67c13a41cf4ea65c5098'}]},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z'},
#  {'id': '17993595537',
#   'type': 'ForkEvent',
#   'actor': {'id': 88230974,
#    'login': 'murphymomo',
#    'display_login': 'murphymomo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/murphymomo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88230974?'},
#   'repo': {'id': 259169614,
#    'name': 'espressif/esp-dev-kits',
#    'url': 'https://api.github.com/repos/espressif/esp-dev-kits'},
#   'payload': {'forkee': {'id': 406691650,
#     'node_id': 'MDEwOlJlcG9zaXRvcnk0MDY2OTE2NTA=',
#     'name': 'esp-dev-kits',
#     'full_name': 'murphymomo/esp-dev-kits',
#     'private': False,
#     'owner': {'login': 'murphymomo',
#      'id': 88230974,
#      'node_id': 'MDQ6VXNlcjg4MjMwOTc0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/88230974?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/murphymomo',
#      'html_url': 'https://github.com/murphymomo',
#      'followers_url': 'https://api.github.com/users/murphymomo/followers',
#      'following_url': 'https://api.github.com/users/murphymomo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/murphymomo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/murphymomo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/murphymomo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/murphymomo/orgs',
#      'repos_url': 'https://api.github.com/users/murphymomo/repos',
#      'events_url': 'https://api.github.com/users/murphymomo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/murphymomo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/murphymomo/esp-dev-kits',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/murphymomo/esp-dev-kits',
#     'forks_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/forks',
#     'keys_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/teams',
#     'hooks_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/hooks',
#     'issue_events_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/events',
#     'assignees_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/tags',
#     'blobs_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/languages',
#     'stargazers_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/stargazers',
#     'contributors_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/contributors',
#     'subscribers_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/subscribers',
#     'subscription_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/subscription',
#     'commits_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/merges',
#     'archive_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/downloads',
#     'issues_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/murphymomo/esp-dev-kits/deployments',
#     'created_at': '2021-09-15T09:14:31Z',
#     'updated_at': '2021-09-15T01:51:30Z',
#     'pushed_at': '2021-06-17T03:26:35Z',
#     'git_url': 'git://github.com/murphymomo/esp-dev-kits.git',
#     'ssh_url': 'git@github.com:murphymomo/esp-dev-kits.git',
#     'clone_url': 'https://github.com/murphymomo/esp-dev-kits.git',
#     'svn_url': 'https://github.com/murphymomo/esp-dev-kits',
#     'homepage': None,
#     'size': 124816,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2021-09-15T09:14:32Z',
#   'org': {'id': 9460735,
#    'login': 'espressif',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/espressif',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9460735?'}}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                           type  \
# 0   17993595718                      PushEvent
# 1   17993595682               PullRequestEvent
# 2   17993595703                      PushEvent
# 3   17993595694                      PushEvent
# 4   17993595697                      PushEvent
# 5   17993595690                      PushEvent
# 6   17993595676                      PushEvent
# 7   17993595664                    IssuesEvent
# 8   17993595675              IssueCommentEvent
# 9   17993595667               PullRequestEvent
# 10  17993595648  PullRequestReviewCommentEvent
# 11  17993595649                    CreateEvent
# 12  17993595604                      PushEvent
# 13  17993595612               PullRequestEvent
# 14  17993595598                    CreateEvent
# 15  17993595609                      PushEvent
# 16  17993595596  PullRequestReviewCommentEvent
# 17  17993595611               PullRequestEvent
# 18  17993595591         PullRequestReviewEvent
# 19  17993595597                    CreateEvent
# 20  17993595570                      PushEvent
# 21  17993595600                    CreateEvent
# 22  17993595539                      PushEvent
# 23  17993595572         PullRequestReviewEvent
# 24  17993595553                      PushEvent
# 25  17993595531                      PushEvent
# 26  17993595549                      PushEvent
# 27  17993595543                      PushEvent
# 28  17993595558                      PushEvent
# 29  17993595537                      ForkEvent
#
#                                                 actor  \
# 0   {'id': 43733305, 'login': 'yanonono', 'display...
# 1   {'id': 41898282, 'login': 'github-actions[bot]...
# 2   {'id': 7920370, 'login': 'dreamerminsk', 'disp...
# 3   {'id': 64201251, 'login': 'tachibanatanaka', '...
# 4   {'id': 18388400, 'login': 'Rackar', 'display_l...
# 5   {'id': 27745384, 'login': 'waiizen', 'display_...
# 6   {'id': 32444997, 'login': 'huymach91', 'displa...
# 7   {'id': 24226825, 'login': 'noliveleger', 'disp...
# 8   {'id': 49699333, 'login': 'dependabot[bot]', '...
# 9   {'id': 495403, 'login': 'reidhoch', 'display_l...
# 10  {'id': 40627776, 'login': 'geoffw0', 'display_...
# 11  {'id': 68048606, 'login': 'peterlimjr', 'displ...
# 12  {'id': 64637987, 'login': 'vm3192', 'display_l...
# 13  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 14  {'id': 66124092, 'login': 'Nappy-Says', 'displ...
# 15  {'id': 60003240, 'login': 'easychessanimations...
# 16  {'id': 9334190, 'login': 'mullefel', 'display_...
# 17  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 18  {'id': 40627776, 'login': 'geoffw0', 'display_...
# 19  {'id': 28550490, 'login': 'wq243750083', 'disp...
# 20  {'id': 20096058, 'login': 'algitbot', 'display...
# 21  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 22  {'id': 1790109, 'login': 'toby1knby', 'display...
# 23  {'id': 9334190, 'login': 'mullefel', 'display_...
# 24  {'id': 41898282, 'login': 'github-actions[bot]...
# 25  {'id': 41898282, 'login': 'github-actions[bot]...
# 26  {'id': 89893383, 'login': 'beom24685', 'displa...
# 27  {'id': 8517910, 'login': 'LombiqBot', 'display...
# 28  {'id': 6679870, 'login': 'suzutan', 'display_l...
# 29  {'id': 88230974, 'login': 'murphymomo', 'displ...
#
#                                                  repo  \
# 0   {'id': 183440182, 'name': 'yanonono/booth-upda...
# 1   {'id': 172341180, 'name': 'lacolaco/contributo...
# 2   {'id': 401275574, 'name': 'dreamerminsk/gowiki...
# 3   {'id': 406691023, 'name': 'tachibanatanaka/Jak...
# 4   {'id': 402367765, 'name': 'Rackar/powerTools',...
# 5   {'id': 405980972, 'name': 'waiizen/Questionnai...
# 6   {'id': 396354169, 'name': 'huymach91/hm-angula...
# 7   {'id': 50376388, 'name': 'kobotoolbox/formpack...
# 8   {'id': 377837702, 'name': 'bbeesley/build-test...
# 9   {'id': 371758553, 'name': 'reidhoch/oeis-seq',...
# 10  {'id': 143040428, 'name': 'github/codeql', 'ur...
# 11  {'id': 406691637, 'name': 'CheersLand/cheersla...
# 12  {'id': 403933855, 'name': 'vm3192/BEIT', 'url'...
# 13  {'id': 360742253, 'name': 'beyondstorage/go-st...
# 14  {'id': 406636199, 'name': 'Nappy-Says/stats', ...
# 15  {'id': 302893590, 'name': 'easychessanimations...
# 16  {'id': 181679762, 'name': 'integritee-network/...
# 17  {'id': 130705213, 'name': 'landtechnologies/ge...
# 18  {'id': 143040428, 'name': 'github/codeql', 'ur...
# 19  {'id': 406691644, 'name': 'wq243750083/create-...
# 20  {'id': 19851667, 'name': 'alpinelinux/aports',...
# 21  {'id': 130705213, 'name': 'landtechnologies/ge...
# 22  {'id': 375498085, 'name': 'nais/handbook', 'ur...
# 23  {'id': 181679762, 'name': 'integritee-network/...
# 24  {'id': 13595212, 'name': 'pubstandards/pubstan...
# 25  {'id': 314087409, 'name': 'b0kch01/b0kch01', '...
# 26  {'id': 401928750, 'name': 'beom24685/beom24685...
# 27  {'id': 86929735, 'name': 'Lombiq/Orchard', 'ur...
# 28  {'id': 318534348, 'name': 'patioglass/adjustim...
# 29  {'id': 259169614, 'name': 'espressif/esp-dev-k...
#
#                                               payload  public  \
# 0   {'push_id': 7938246757, 'size': 1, 'distinct_s...    True
# 1   {'action': 'opened', 'number': 859, 'pull_requ...    True
# 2   {'push_id': 7938246778, 'size': 3, 'distinct_s...    True
# 3   {'push_id': 7938246753, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 7938246765, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 7938246770, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 7938246752, 'size': 2, 'distinct_s...    True
# 7   {'action': 'closed', 'issue': {'url': 'https:/...    True
# 8   {'action': 'created', 'issue': {'url': 'https:...    True
# 9   {'action': 'closed', 'number': 53, 'pull_reque...    True
# 10  {'action': 'created', 'comment': {'url': 'http...    True
# 11  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 12  {'push_id': 7938246680, 'size': 1, 'distinct_s...    True
# 13  {'action': 'opened', 'number': 29, 'pull_reque...    True
# 14  {'ref': 'master', 'ref_type': 'branch', 'maste...    True
# 15  {'push_id': 7938246732, 'size': 1, 'distinct_s...    True
# 16  {'action': 'created', 'comment': {'url': 'http...    True
# 17  {'action': 'opened', 'number': 4, 'pull_reques...    True
# 18  {'action': 'created', 'review': {'id': 7548684...    True
# 19  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 20  {'push_id': 7938245842, 'size': 1, 'distinct_s...    True
# 21  {'ref': 'dependabot/npm_and_yarn/handlebars-4....    True
# 22  {'push_id': 7938246712, 'size': 2, 'distinct_s...    True
# 23  {'action': 'created', 'review': {'id': 7548684...    True
# 24  {'push_id': 7938246724, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 7938246681, 'size': 1, 'distinct_s...    True
# 26  {'push_id': 7938246729, 'size': 1, 'distinct_s...    True
# 27  {'push_id': 7938246710, 'size': 0, 'distinct_s...    True
# 28  {'push_id': 7938246702, 'size': 1, 'distinct_s...    True
# 29  {'forkee': {'id': 406691650, 'node_id': 'MDEwO...    True
#
#               created_at                                                org
# 0   2021-09-15T09:14:32Z                                                NaN
# 1   2021-09-15T09:14:32Z                                                NaN
# 2   2021-09-15T09:14:32Z                                                NaN
# 3   2021-09-15T09:14:32Z                                                NaN
# 4   2021-09-15T09:14:32Z                                                NaN
# 5   2021-09-15T09:14:32Z                                                NaN
# 6   2021-09-15T09:14:32Z                                                NaN
# 7   2021-09-15T09:14:32Z  {'id': 5543677, 'login': 'kobotoolbox', 'grava...
# 8   2021-09-15T09:14:32Z                                                NaN
# 9   2021-09-15T09:14:32Z                                                NaN
# 10  2021-09-15T09:14:31Z  {'id': 9919, 'login': 'github', 'gravatar_id':...
# 11  2021-09-15T09:14:32Z  {'id': 88068968, 'login': 'CheersLand', 'grava...
# 12  2021-09-15T09:14:32Z                                                NaN
# 13  2021-09-15T09:14:32Z  {'id': 67630853, 'login': 'beyondstorage', 'gr...
# 14  2021-09-15T09:14:32Z                                                NaN
# 15  2021-09-15T09:14:32Z                                                NaN
# 16  2021-09-15T09:14:31Z  {'id': 86358325, 'login': 'integritee-network'...
# 17  2021-09-15T09:14:32Z  {'id': 13318355, 'login': 'landtechnologies', ...
# 18  2021-09-15T09:14:32Z  {'id': 9919, 'login': 'github', 'gravatar_id':...
# 19  2021-09-15T09:14:32Z                                                NaN
# 20  2021-09-15T09:14:32Z  {'id': 7600810, 'login': 'alpinelinux', 'grava...
# 21  2021-09-15T09:14:32Z  {'id': 13318355, 'login': 'landtechnologies', ...
# 22  2021-09-15T09:14:32Z  {'id': 29488289, 'login': 'nais', 'gravatar_id...
# 23  2021-09-15T09:14:32Z  {'id': 86358325, 'login': 'integritee-network'...
# 24  2021-09-15T09:14:32Z  {'id': 7117218, 'login': 'pubstandards', 'grav...
# 25  2021-09-15T09:14:32Z                                                NaN
# 26  2021-09-15T09:14:32Z                                                NaN
# 27  2021-09-15T09:14:32Z  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# 28  2021-09-15T09:14:32Z                                                NaN
# 29  2021-09-15T09:14:32Z  {'id': 9460735, 'login': 'espressif', 'gravata...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id                           type  public            created_at  \
# 0   17993595718                      PushEvent    True  2021-09-15T09:14:32Z
# 1   17993595682               PullRequestEvent    True  2021-09-15T09:14:32Z
# 2   17993595703                      PushEvent    True  2021-09-15T09:14:32Z
# 3   17993595694                      PushEvent    True  2021-09-15T09:14:32Z
# 4   17993595697                      PushEvent    True  2021-09-15T09:14:32Z
# 5   17993595690                      PushEvent    True  2021-09-15T09:14:32Z
# 6   17993595676                      PushEvent    True  2021-09-15T09:14:32Z
# 7   17993595664                    IssuesEvent    True  2021-09-15T09:14:32Z
# 8   17993595675              IssueCommentEvent    True  2021-09-15T09:14:32Z
# 9   17993595667               PullRequestEvent    True  2021-09-15T09:14:32Z
# 10  17993595648  PullRequestReviewCommentEvent    True  2021-09-15T09:14:31Z
# 11  17993595649                    CreateEvent    True  2021-09-15T09:14:32Z
# 12  17993595604                      PushEvent    True  2021-09-15T09:14:32Z
# 13  17993595612               PullRequestEvent    True  2021-09-15T09:14:32Z
# 14  17993595598                    CreateEvent    True  2021-09-15T09:14:32Z
# 15  17993595609                      PushEvent    True  2021-09-15T09:14:32Z
# 16  17993595596  PullRequestReviewCommentEvent    True  2021-09-15T09:14:31Z
# 17  17993595611               PullRequestEvent    True  2021-09-15T09:14:32Z
# 18  17993595591         PullRequestReviewEvent    True  2021-09-15T09:14:32Z
# 19  17993595597                    CreateEvent    True  2021-09-15T09:14:32Z
# 20  17993595570                      PushEvent    True  2021-09-15T09:14:32Z
# 21  17993595600                    CreateEvent    True  2021-09-15T09:14:32Z
# 22  17993595539                      PushEvent    True  2021-09-15T09:14:32Z
# 23  17993595572         PullRequestReviewEvent    True  2021-09-15T09:14:32Z
# 24  17993595553                      PushEvent    True  2021-09-15T09:14:32Z
# 25  17993595531                      PushEvent    True  2021-09-15T09:14:32Z
# 26  17993595549                      PushEvent    True  2021-09-15T09:14:32Z
# 27  17993595543                      PushEvent    True  2021-09-15T09:14:32Z
# 28  17993595558                      PushEvent    True  2021-09-15T09:14:32Z
# 29  17993595537                      ForkEvent    True  2021-09-15T09:14:32Z
#
#     actor.id          actor.login  actor.display_login actor.gravatar_id  \
# 0   43733305             yanonono             yanonono
# 1   41898282  github-actions[bot]       github-actions
# 2    7920370         dreamerminsk         dreamerminsk
# 3   64201251      tachibanatanaka      tachibanatanaka
# 4   18388400               Rackar               Rackar
# 5   27745384              waiizen              waiizen
# 6   32444997            huymach91            huymach91
# 7   24226825          noliveleger          noliveleger
# 8   49699333      dependabot[bot]           dependabot
# 9     495403             reidhoch             reidhoch
# 10  40627776              geoffw0              geoffw0
# 11  68048606           peterlimjr           peterlimjr
# 12  64637987               vm3192               vm3192
# 13  49699333      dependabot[bot]           dependabot
# 14  66124092           Nappy-Says           Nappy-Says
# 15  60003240  easychessanimations  easychessanimations
# 16   9334190             mullefel             mullefel
# 17  49699333      dependabot[bot]           dependabot
# 18  40627776              geoffw0              geoffw0
# 19  28550490          wq243750083          wq243750083
# 20  20096058             algitbot             algitbot
# 21  49699333      dependabot[bot]           dependabot
# 22   1790109            toby1knby            toby1knby
# 23   9334190             mullefel             mullefel
# 24  41898282  github-actions[bot]       github-actions
# 25  41898282  github-actions[bot]       github-actions
# 26  89893383            beom24685            beom24685
# 27   8517910            LombiqBot            LombiqBot
# 28   6679870              suzutan              suzutan
# 29  88230974           murphymomo           murphymomo
#
#                                            actor.url  \
# 0              https://api.github.com/users/yanonono
# 1   https://api.github.com/users/github-actions[bot]
# 2          https://api.github.com/users/dreamerminsk
# 3       https://api.github.com/users/tachibanatanaka
# 4                https://api.github.com/users/Rackar
# 5               https://api.github.com/users/waiizen
# 6             https://api.github.com/users/huymach91
# 7           https://api.github.com/users/noliveleger
# 8       https://api.github.com/users/dependabot[bot]
# 9              https://api.github.com/users/reidhoch
# 10              https://api.github.com/users/geoffw0
# 11           https://api.github.com/users/peterlimjr
# 12               https://api.github.com/users/vm3192
# 13      https://api.github.com/users/dependabot[bot]
# 14           https://api.github.com/users/Nappy-Says
# 15  https://api.github.com/users/easychessanimations
# 16             https://api.github.com/users/mullefel
# 17      https://api.github.com/users/dependabot[bot]
# 18              https://api.github.com/users/geoffw0
# 19          https://api.github.com/users/wq243750083
# 20             https://api.github.com/users/algitbot
# 21      https://api.github.com/users/dependabot[bot]
# 22            https://api.github.com/users/toby1knby
# 23             https://api.github.com/users/mullefel
# 24  https://api.github.com/users/github-actions[bot]
# 25  https://api.github.com/users/github-actions[bot]
# 26            https://api.github.com/users/beom24685
# 27            https://api.github.com/users/LombiqBot
# 28              https://api.github.com/users/suzutan
# 29           https://api.github.com/users/murphymomo
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/43733305?  ...
# 1   https://avatars.githubusercontent.com/u/41898282?  ...
# 2    https://avatars.githubusercontent.com/u/7920370?  ...
# 3   https://avatars.githubusercontent.com/u/64201251?  ...
# 4   https://avatars.githubusercontent.com/u/18388400?  ...
# 5   https://avatars.githubusercontent.com/u/27745384?  ...
# 6   https://avatars.githubusercontent.com/u/32444997?  ...
# 7   https://avatars.githubusercontent.com/u/24226825?  ...
# 8   https://avatars.githubusercontent.com/u/49699333?  ...
# 9     https://avatars.githubusercontent.com/u/495403?  ...
# 10  https://avatars.githubusercontent.com/u/40627776?  ...
# 11  https://avatars.githubusercontent.com/u/68048606?  ...
# 12  https://avatars.githubusercontent.com/u/64637987?  ...
# 13  https://avatars.githubusercontent.com/u/49699333?  ...
# 14  https://avatars.githubusercontent.com/u/66124092?  ...
# 15  https://avatars.githubusercontent.com/u/60003240?  ...
# 16   https://avatars.githubusercontent.com/u/9334190?  ...
# 17  https://avatars.githubusercontent.com/u/49699333?  ...
# 18  https://avatars.githubusercontent.com/u/40627776?  ...
# 19  https://avatars.githubusercontent.com/u/28550490?  ...
# 20  https://avatars.githubusercontent.com/u/20096058?  ...
# 21  https://avatars.githubusercontent.com/u/49699333?  ...
# 22   https://avatars.githubusercontent.com/u/1790109?  ...
# 23   https://avatars.githubusercontent.com/u/9334190?  ...
# 24  https://avatars.githubusercontent.com/u/41898282?  ...
# 25  https://avatars.githubusercontent.com/u/41898282?  ...
# 26  https://avatars.githubusercontent.com/u/89893383?  ...
# 27   https://avatars.githubusercontent.com/u/8517910?  ...
# 28   https://avatars.githubusercontent.com/u/6679870?  ...
# 29  https://avatars.githubusercontent.com/u/88230974?  ...
#
#     payload.forkee.archived payload.forkee.disabled  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# 5                       NaN                     NaN
# 6                       NaN                     NaN
# 7                       NaN                     NaN
# 8                       NaN                     NaN
# 9                       NaN                     NaN
# 10                      NaN                     NaN
# 11                      NaN                     NaN
# 12                      NaN                     NaN
# 13                      NaN                     NaN
# 14                      NaN                     NaN
# 15                      NaN                     NaN
# 16                      NaN                     NaN
# 17                      NaN                     NaN
# 18                      NaN                     NaN
# 19                      NaN                     NaN
# 20                      NaN                     NaN
# 21                      NaN                     NaN
# 22                      NaN                     NaN
# 23                      NaN                     NaN
# 24                      NaN                     NaN
# 25                      NaN                     NaN
# 26                      NaN                     NaN
# 27                      NaN                     NaN
# 28                      NaN                     NaN
# 29                    False                   False
#
#    payload.forkee.open_issues_count  payload.forkee.license  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
# 5                               NaN                     NaN
# 6                               NaN                     NaN
# 7                               NaN                     NaN
# 8                               NaN                     NaN
# 9                               NaN                     NaN
# 10                              NaN                     NaN
# 11                              NaN                     NaN
# 12                              NaN                     NaN
# 13                              NaN                     NaN
# 14                              NaN                     NaN
# 15                              NaN                     NaN
# 16                              NaN                     NaN
# 17                              NaN                     NaN
# 18                              NaN                     NaN
# 19                              NaN                     NaN
# 20                              NaN                     NaN
# 21                              NaN                     NaN
# 22                              NaN                     NaN
# 23                              NaN                     NaN
# 24                              NaN                     NaN
# 25                              NaN                     NaN
# 26                              NaN                     NaN
# 27                              NaN                     NaN
# 28                              NaN                     NaN
# 29                              0.0                     NaN
#
#     payload.forkee.allow_forking  payload.forkee.forks  \
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
# 6                            NaN                   NaN
# 7                            NaN                   NaN
# 8                            NaN                   NaN
# 9                            NaN                   NaN
# 10                           NaN                   NaN
# 11                           NaN                   NaN
# 12                           NaN                   NaN
# 13                           NaN                   NaN
# 14                           NaN                   NaN
# 15                           NaN                   NaN
# 16                           NaN                   NaN
# 17                           NaN                   NaN
# 18                           NaN                   NaN
# 19                           NaN                   NaN
# 20                           NaN                   NaN
# 21                           NaN                   NaN
# 22                           NaN                   NaN
# 23                           NaN                   NaN
# 24                           NaN                   NaN
# 25                           NaN                   NaN
# 26                           NaN                   NaN
# 27                           NaN                   NaN
# 28                           NaN                   NaN
# 29                          True                   0.0
#
#    payload.forkee.open_issues payload.forkee.watchers  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# 5                         NaN                     NaN
# 6                         NaN                     NaN
# 7                         NaN                     NaN
# 8                         NaN                     NaN
# 9                         NaN                     NaN
# 10                        NaN                     NaN
# 11                        NaN                     NaN
# 12                        NaN                     NaN
# 13                        NaN                     NaN
# 14                        NaN                     NaN
# 15                        NaN                     NaN
# 16                        NaN                     NaN
# 17                        NaN                     NaN
# 18                        NaN                     NaN
# 19                        NaN                     NaN
# 20                        NaN                     NaN
# 21                        NaN                     NaN
# 22                        NaN                     NaN
# 23                        NaN                     NaN
# 24                        NaN                     NaN
# 25                        NaN                     NaN
# 26                        NaN                     NaN
# 27                        NaN                     NaN
# 28                        NaN                     NaN
# 29                        0.0                     0.0
#
#    payload.forkee.default_branch payload.forkee.public
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
# 6                            NaN                   NaN
# 7                            NaN                   NaN
# 8                            NaN                   NaN
# 9                            NaN                   NaN
# 10                           NaN                   NaN
# 11                           NaN                   NaN
# 12                           NaN                   NaN
# 13                           NaN                   NaN
# 14                           NaN                   NaN
# 15                           NaN                   NaN
# 16                           NaN                   NaN
# 17                           NaN                   NaN
# 18                           NaN                   NaN
# 19                           NaN                   NaN
# 20                           NaN                   NaN
# 21                           NaN                   NaN
# 22                           NaN                   NaN
# 23                           NaN                   NaN
# 24                           NaN                   NaN
# 25                           NaN                   NaN
# 26                           NaN                   NaN
# 27                           NaN                   NaN
# 28                           NaN                   NaN
# 29                          main                  True
#
# [30 rows x 602 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'timestamp': 1631698188,
#  'iss_position': {'latitude': '-30.7637', 'longitude': '-32.2173'}}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack Spain
coordinates = {"lat": 41.397730, "lon": 2.190290}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029'

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029")

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1631686788,
#   'latitude': 41.39773,
#   'longitude': 2.19029,
#   'passes': 5},
#  'response': [{'duration': 385, 'risetime': 1631728669},
#   {'duration': 645, 'risetime': 1631734306},
#   {'duration': 629, 'risetime': 1631740132},
#   {'duration': 576, 'risetime': 1631746020},
#   {'duration': 611, 'risetime': 1631751870}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1604442746)
# Out:
# datetime.datetime(2020, 11, 3, 23, 32, 26)

# %%
pd.to_datetime(1604442746, unit="s")
# Out:
# Timestamp('2020-11-03 22:32:26')

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1,'/content/drive/MyDrive/Credentials/')
from config import *

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

## https://rapidapi.com/community/api/open-weather-map/
url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2c5ac21603bb> in <module>
#       9
#      10 headers = {
# ---> 11     'x-rapidapi-key': x_rapidapi_key,
#      12     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      13     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1631658033, 'latitude': 41.39773, 'longitude': 2.19029, 'passes': 5}, 'response': [{'duration': 576, 'risetime': 1631662447}, {'duration': 628, 'risetime': 1631668284}, {'duration': 651, 'risetime': 1631674093}, {'duration': 421, 'risetime': 1631679977}, {'duration': 385, 'risetime': 1631728669}]}
# dict

# %%
results.keys()
# Out:
# dict_keys(['message', 'request', 'response'])

# %%
results['data']
# Out:
# [{'app_temp': 25.4,
#   'aqi': 68,
#   'city_name': 'Zarzalejo',
#   'clouds': 75,
#   'country_code': 'ES',
#   'datetime': '2021-06-15:08',
#   'dewpt': 12.4,
#   'dhi': 92.52,
#   'dni': 808.24,
#   'elev_angle': 34.18,
#   'ghi': 540.97,
#   'h_angle': -45,
#   'lat': 40.55,
#   'lon': -4.2,
#   'ob_time': '2021-06-15 08:00',
#   'pod': 'd',
#   'precip': 0,
#   'pres': 945.1,
#   'rh': 44,
#   'slp': 1018.9,
#   'snow': 0,
#   'solar_rad': 378.2,
#   'state_code': '29',
#   'station': 'F7959',
#   'sunrise': '04:44',
#   'sunset': '19:48',
#   'temp': 25.6,
#   'timezone': 'Europe/Madrid',
#   'ts': 1623744000,
#   'uv': 5.89272,
#   'vis': 5,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 44,
#   'wind_spd': 1}]

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...

# %%
results['data']
# Out:
# [{'app_temp': 22.4,
#   'clouds': 69,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 69,
#   'datetime': '2021-06-15:09',
#   'dewpt': 7.9,
#   'dhi': 103.41,
#   'dni': 868.79,
#   'ghi': 717.09,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.001953125,
#   'pres': 884.145,
#   'rh': 39,
#   'slp': 1018.79,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 564.782,
#   'temp': 23,
#   'timestamp_local': '2021-06-15T11:00:00',
#   'timestamp_utc': '2021-06-15T09:00:00',
#   'ts': 1623747600,
#   'uv': 2.81755,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 78,
#   'wind_gust_spd': 11.5571,
#   'wind_spd': 4.07371},
#  {'app_temp': 26.2,
#   'clouds': 38,
#   'clouds_hi': 2,
#   'clouds_low': 0,
#   'clouds_mid': 39,
#   'datetime': '2021-06-15:12',
#   'dewpt': 6,
#   'dhi': 117.62,
#   'dni': 937.94,
#   'ghi': 1002.88,
#   'ozone': 328,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.112,
#   'rh': 27,
#   'slp': 1016.89,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 974.853,
#   'temp': 26.8,
#   'timestamp_local': '2021-06-15T14:00:00',
#   'timestamp_utc': '2021-06-15T12:00:00',
#   'ts': 1623758400,
#   'uv': 7.58151,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 111,
#   'wind_gust_spd': 11.7118,
#   'wind_spd': 5.50618},
#  {'app_temp': 26.9,
#   'clouds': 76,
#   'clouds_hi': 43,
#   'clouds_low': 0,
#   'clouds_mid': 56,
#   'datetime': '2021-06-15:15',
#   'dewpt': 5.4,
#   'dhi': 107.98,
#   'dni': 892.15,
#   'ghi': 801.62,
#   'ozone': 323,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.048828125,
#   'pres': 881.339,
#   'rh': 24,
#   'slp': 1014.46,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 565.139,
#   'temp': 28.1,
#   'timestamp_local': '2021-06-15T17:00:00',
#   'timestamp_utc': '2021-06-15T15:00:00',
#   'ts': 1623769200,
#   'uv': 3.15302,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 164,
#   'wind_gust_spd': 12.2921,
#   'wind_spd': 4.28592},
#  {'app_temp': 25.8,
#   'clouds': 80,
#   'clouds_hi': 12,
#   'clouds_low': 0,
#   'clouds_mid': 78,
#   'datetime': '2021-06-15:18',
#   'dewpt': 6,
#   'dhi': 68.69,
#   'dni': 647.18,
#   'ghi': 262.69,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.021484375,
#   'pres': 880.719,
#   'rh': 28,
#   'slp': 1013.91,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 170.431,
#   'temp': 26.4,
#   'timestamp_local': '2021-06-15T20:00:00',
#   'timestamp_utc': '2021-06-15T18:00:00',
#   'ts': 1623780000,
#   'uv': 0.813903,
#   'vis': 19.2,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 169,
#   'wind_gust_spd': 10.1157,
#   'wind_spd': 4.75035},
#  {'app_temp': 20.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 8,
#   'clouds_mid': 81,
#   'datetime': '2021-06-15:21',
#   'dewpt': 9.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 319,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.095703125,
#   'pres': 881.045,
#   'rh': 48,
#   'slp': 1015.38,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 21.4,
#   'timestamp_local': '2021-06-15T23:00:00',
#   'timestamp_utc': '2021-06-15T21:00:00',
#   'ts': 1623790800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 7.37562,
#   'wind_spd': 2.08412},
#  {'app_temp': 18.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 4,
#   'clouds_mid': 70,
#   'datetime': '2021-06-16:00',
#   'dewpt': 11.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 324.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.33984375,
#   'pres': 881.915,
#   'rh': 67,
#   'slp': 1017.05,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.4,
#   'timestamp_local': '2021-06-16T02:00:00',
#   'timestamp_utc': '2021-06-16T00:00:00',
#   'ts': 1623801600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 90,
#   'wind_gust_spd': 9.4193,
#   'wind_spd': 1.0167},
#  {'app_temp': 17.4,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 24,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:03',
#   'dewpt': 11,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 323,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.068359375,
#   'pres': 879.474,
#   'rh': 67,
#   'slp': 1014.45,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 17.4,
#   'timestamp_local': '2021-06-16T05:00:00',
#   'timestamp_utc': '2021-06-16T03:00:00',
#   'ts': 1623812400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 62,
#   'wind_gust_spd': 11.6762,
#   'wind_spd': 3.34812},
#  {'app_temp': 17,
#   'clouds': 62,
#   'clouds_hi': 0,
#   'clouds_low': 21,
#   'clouds_mid': 54,
#   'datetime': '2021-06-16:06',
#   'dewpt': 10.8,
#   'dhi': 55.42,
#   'dni': 536.17,
#   'ghi': 159.75,
#   'ozone': 321.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.611,
#   'rh': 69,
#   'slp': 1014.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.165,
#   'temp': 17,
#   'timestamp_local': '2021-06-16T08:00:00',
#   'timestamp_utc': '2021-06-16T06:00:00',
#   'ts': 1623823200,
#   'uv': 0.894861,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 11.2242,
#   'wind_spd': 2.06524},
#  {'app_temp': 19.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 30,
#   'clouds_mid': 51,
#   'datetime': '2021-06-16:09',
#   'dewpt': 11.3,
#   'dhi': 103.38,
#   'dni': 868.55,
#   'ghi': 716.68,
#   'ozone': 318.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.427,
#   'rh': 60,
#   'slp': 1014.29,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 179.17,
#   'temp': 19.7,
#   'timestamp_local': '2021-06-16T11:00:00',
#   'timestamp_utc': '2021-06-16T09:00:00',
#   'ts': 1623834000,
#   'uv': 1.67897,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 97,
#   'wind_gust_spd': 11.2175,
#   'wind_spd': 2.20589},
#  {'app_temp': 22.9,
#   'clouds': 56,
#   'clouds_hi': 8,
#   'clouds_low': 30,
#   'clouds_mid': 38,
#   'datetime': '2021-06-16:12',
#   'dewpt': 11.1,
#   'dhi': 117.6,
#   'dni': 937.81,
#   'ghi': 1002.87,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.146484375,
#   'pres': 878.984,
#   'rh': 48,
#   'slp': 1013.18,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 898.122,
#   'temp': 23.2,
#   'timestamp_local': '2021-06-16T14:00:00',
#   'timestamp_utc': '2021-06-16T12:00:00',
#   'ts': 1623844800,
#   'uv': 6.33404,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 13.1602,
#   'wind_spd': 4.33191},
#  {'app_temp': 23.8,
#   'clouds': 82,
#   'clouds_hi': 8,
#   'clouds_low': 64,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:15',
#   'dewpt': 8.7,
#   'dhi': 108,
#   'dni': 892.19,
#   'ghi': 802.25,
#   'ozone': 328.25,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.01171875,
#   'pres': 876.801,
#   'rh': 38,
#   'slp': 1010.28,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 495.815,
#   'temp': 24.3,
#   'timestamp_local': '2021-06-16T17:00:00',
#   'timestamp_utc': '2021-06-16T15:00:00',
#   'ts': 1623855600,
#   'uv': 2.88811,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 194,
#   'wind_gust_spd': 13.1986,
#   'wind_spd': 6.2823},
#  {'app_temp': 22.4,
#   'clouds': 82,
#   'clouds_hi': 19,
#   'clouds_low': 56,
#   'clouds_mid': 69,
#   'datetime': '2021-06-16:18',
#   'dewpt': 9.1,
#   'dhi': 68.79,
#   'dni': 647.94,
#   'ghi': 263.66,
#   'ozone': 326.75,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.06640625,
#   'pres': 876.411,
#   'rh': 42,
#   'slp': 1010.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 162.95,
#   'temp': 22.9,
#   'timestamp_local': '2021-06-16T20:00:00',
#   'timestamp_utc': '2021-06-16T18:00:00',
#   'ts': 1623866400,
#   'uv': 0.793887,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SW',
#   'wind_cdir_full': 'southwest',
#   'wind_dir': 220,
#   'wind_gust_spd': 11.1933,
#   'wind_spd': 3.96155},
#  {'app_temp': 18.1,
#   'clouds': 94,
#   'clouds_hi': 62,
#   'clouds_low': 56,
#   'clouds_mid': 84,
#   'datetime': '2021-06-16:21',
#   'dewpt': 10.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.193359375,
#   'pres': 878.112,
#   'rh': 59,
#   'slp': 1012.83,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.6,
#   'timestamp_local': '2021-06-16T23:00:00',
#   'timestamp_utc': '2021-06-16T21:00:00',
#   'ts': 1623877200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 126,
#   'wind_gust_spd': 7.01437,
#   'wind_spd': 1.32861},
#  {'app_temp': 15.8,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2021-06-17:00',
#   'dewpt': 10.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.269,
#   'rh': 72,
#   'slp': 1012.48,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 15.8,
#   'timestamp_local': '2021-06-17T02:00:00',
#   'timestamp_utc': '2021-06-17T00:00:00',
#   'ts': 1623888000,
#   'uv': 0,
#   'vis': 10.008,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 327,
#   'wind_gust_spd': 6.08424,
#   'wind_spd': 1.71289},
#  {'app_temp': 14.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 27,
#   'clouds_mid': 2,
#   'datetime': '2021-06-17:03',
#   'dewpt': 10.6,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 330.75,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.7,
#   'rh': 78,
#   'slp': 1011.99,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.8,
#   'timestamp_local': '2021-06-17T05:00:00',
#   'timestamp_utc': '2021-06-17T03:00:00',
#   'ts': 1623898800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 2,
#   'wind_gust_spd': 5.55667,
#   'wind_spd': 1.72096},
#  {'app_temp': 15.5,
#   'clouds': 88,
#   'clouds_hi': 67,
#   'clouds_low': 37,
#   'clouds_mid': 45,
#   'datetime': '2021-06-17:06',
#   'dewpt': 11.7,
#   'dhi': 55.36,
#   'dni': 535.63,
#   'ghi': 159.4,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.228,
#   'rh': 80,
#   'slp': 1011.42,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 81.9911,
#   'temp': 15.5,
#   'timestamp_local': '2021-06-17T08:00:00',
#   'timestamp_utc': '2021-06-17T06:00:00',
#   'ts': 1623909600,
#   'uv': 0.608304,
#   'vis': 10.728,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 5,
#   'wind_gust_spd': 4.37833,
#   'wind_spd': 1.08316},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 72,
#   'clouds_mid': 30,
#   'datetime': '2021-06-17:09',
#   'dewpt': 13.5,
#   'dhi': 103.34,
#   'dni': 868.31,
#   'ghi': 716.21,
#   'ozone': 339.25,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.75,
#   'pres': 876.576,
#   'rh': 80,
#   'slp': 1011.65,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.08,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T11:00:00',
#   'timestamp_utc': '2021-06-17T09:00:00',
#   'ts': 1623920400,
#   'uv': 1.66392,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 137,
#   'wind_gust_spd': 6.34957,
#   'wind_spd': 1.5818},
#  {'app_temp': 17.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 71,
#   'clouds_mid': 33,
#   'datetime': '2021-06-17:12',
#   'dewpt': 14.6,
#   'dhi': 117.59,
#   'dni': 937.68,
#   'ghi': 1002.82,
#   'ozone': 334.75,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.89453125,
#   'pres': 876.039,
#   'rh': 87,
#   'slp': 1011.09,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 190.536,
#   'temp': 17.1,
#   'timestamp_local': '2021-06-17T14:00:00',
#   'timestamp_utc': '2021-06-17T12:00:00',
#   'ts': 1623931200,
#   'uv': 3.18526,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 116,
#   'wind_gust_spd': 5.97595,
#   'wind_spd': 1.59535},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 73,
#   'clouds_mid': 18,
#   'datetime': '2021-06-17:15',
#   'dewpt': 14.8,
#   'dhi': 108.02,
#   'dni': 892.23,
#   'ghi': 802.82,
#   'ozone': 333,
#   'pod': 'd',
#   'pop': 30,
#   'precip': 0.4140625,
#   'pres': 874.932,
#   'rh': 87,
#   'slp': 1009.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 152.536,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T17:00:00',
#   'timestamp_utc': '2021-06-17T15:00:00',
#   'ts': 1623942000,
#   'uv': 2.05182,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 9.99384,
#   'wind_spd': 1.89453},
#  {'app_temp': 16,
#   'clouds': 79,
#   'clouds_hi': 14,
#   'clouds_low': 73,
#   'clouds_mid': 16,
#   'datetime': '2021-06-17:18',
#   'dewpt': 13.9,
#   'dhi': 68.88,
#   'dni': 648.64,
#   'ghi': 264.57,
#   'ozone': 338.75,
#   'pod': 'd',
#   'pop': 65,
#   'precip': 1.90234375,
#   'pres': 875.149,
#   'rh': 89,
#   'slp': 1010.34,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 168.418,
#   'temp': 16,
#   'timestamp_local': '2021-06-17T20:00:00',
#   'timestamp_utc': '2021-06-17T18:00:00',
#   'ts': 1623952800,
#   'uv': 0.821966,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 55,
#   'wind_gust_spd': 11.0891,
#   'wind_spd': 0.200486},
#  {'app_temp': 14.9,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 49,
#   'clouds_mid': 55,
#   'datetime': '2021-06-17:21',
#   'dewpt': 13.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 344.5,
#   'pod': 'n',
#   'pop': 55,
#   'precip': 1.25390625,
#   'pres': 876.497,
#   'rh': 91,
#   'slp': 1012.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.9,
#   'timestamp_local': '2021-06-17T23:00:00',
#   'timestamp_utc': '2021-06-17T21:00:00',
#   'ts': 1623963600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 33,
#   'wind_gust_spd': 6.10028,
#   'wind_spd': 0.601711},
#  {'app_temp': 13.1,
#   'clouds': 12,
#   'clouds_hi': 2,
#   'clouds_low': 4,
#   'clouds_mid': 5,
#   'datetime': '2021-06-18:00',
#   'dewpt': 11.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.513,
#   'rh': 89,
#   'slp': 1012.39,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.1,
#   'timestamp_local': '2021-06-18T02:00:00',
#   'timestamp_utc': '2021-06-18T00:00:00',
#   'ts': 1623974400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 352,
#   'wind_gust_spd': 4.04717,
#   'wind_spd': 0.758533},
#  {'app_temp': 12,
#   'clouds': 50,
#   'clouds_hi': 1,
#   'clouds_low': 50,
#   'clouds_mid': 2,
#   'datetime': '2021-06-18:03',
#   'dewpt': 10.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.03125,
#   'pres': 876.44,
#   'rh': 92,
#   'slp': 1012.57,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T05:00:00',
#   'timestamp_utc': '2021-06-18T03:00:00',
#   'ts': 1623985200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 345,
#   'wind_gust_spd': 6.70735,
#   'wind_spd': 0.87161},
#  {'app_temp': 12,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 78,
#   'clouds_mid': 30,
#   'datetime': '2021-06-18:06',
#   'dewpt': 10.7,
#   'dhi': 55.29,
#   'dni': 535,
#   'ghi': 158.97,
#   'ozone': 343.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.36,
#   'rh': 93,
#   'slp': 1013.68,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 66.33,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T08:00:00',
#   'timestamp_utc': '2021-06-18T06:00:00',
#   'ts': 1623996000,
#   'uv': 0.593585,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 7.49278,
#   'wind_spd': 0.468219},
#  {'app_temp': 19.7,
#   'clouds': 90,
#   'clouds_hi': 90,
#   'clouds_low': 46,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:09',
#   'dewpt': 8.1,
#   'dhi': 103.3,
#   'dni': 868.06,
#   'ghi': 715.69,
#   'ozone': 345,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 45,
#   'slp': 1012.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 344.066,
#   'temp': 20.5,
#   'timestamp_local': '2021-06-18T11:00:00',
#   'timestamp_utc': '2021-06-18T09:00:00',
#   'ts': 1624006800,
#   'uv': 2.0374,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 138,
#   'wind_gust_spd': 5.41016,
#   'wind_spd': 3.7763},
#  {'app_temp': 22.4,
#   'clouds': 24,
#   'clouds_hi': 2,
#   'clouds_low': 24,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:12',
#   'dewpt': 8.8,
#   'dhi': 117.58,
#   'dni': 937.55,
#   'ghi': 1002.73,
#   'ozone': 344.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 40,
#   'slp': 1012,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 997.187,
#   'temp': 23,
#   'timestamp_local': '2021-06-18T14:00:00',
#   'timestamp_utc': '2021-06-18T12:00:00',
#   'ts': 1624017600,
#   'uv': 8.58676,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 147,
#   'wind_gust_spd': 6.69922,
#   'wind_spd': 4.54761},
#  {'app_temp': 23.5,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 63,
#   'clouds_mid': 32,
#   'datetime': '2021-06-18:15',
#   'dewpt': 7.5,
#   'dhi': 108.04,
#   'dni': 892.26,
#   'ghi': 803.36,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905,
#   'rh': 34,
#   'slp': 1009.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 200.84,
#   'temp': 24.2,
#   'timestamp_local': '2021-06-18T17:00:00',
#   'timestamp_utc': '2021-06-18T15:00:00',
#   'ts': 1624028400,
#   'uv': 2.04829,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 5.91797,
#   'wind_spd': 2.26834},
#  {'app_temp': 22.7,
#   'clouds': 64,
#   'clouds_hi': 57,
#   'clouds_low': 18,
#   'clouds_mid': 19,
#   'datetime': '2021-06-18:18',
#   'dewpt': 8.5,
#   'dhi': 68.97,
#   'dni': 649.29,
#   'ghi': 265.41,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 904.5,
#   'rh': 38,
#   'slp': 1008.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 220.884,
#   'temp': 23.3,
#   'timestamp_local': '2021-06-18T20:00:00',
#   'timestamp_utc': '2021-06-18T18:00:00',
#   'ts': 1624039200,
#   'uv': 0.994731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'WSW',
#   'wind_cdir_full': 'west-southwest',
#   'wind_dir': 239,
#   'wind_gust_spd': 4.63281,
#   'wind_spd': 2.69643},
#  {'app_temp': 18.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 6,
#   'clouds_mid': 79,
#   'datetime': '2021-06-18:21',
#   'dewpt': 7.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 340.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905.5,
#   'rh': 50,
#   'slp': 1010.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.3,
#   'timestamp_local': '2021-06-18T23:00:00',
#   'timestamp_utc': '2021-06-18T21:00:00',
#   'ts': 1624050000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 351,
#   'wind_gust_spd': 2.12695,
#   'wind_spd': 2.41283},
#  {'app_temp': 16.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 99,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:00',
#   'dewpt': 10.2,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 337.75,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 905.5,
#   'rh': 68,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 16.1,
#   'timestamp_local': '2021-06-19T02:00:00',
#   'timestamp_utc': '2021-06-19T00:00:00',
#   'ts': 1624060800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 338,
#   'wind_gust_spd': 0.812988,
#   'wind_spd': 0.61213},
#  {'app_temp': 13.4,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:03',
#   'dewpt': 12.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 333.25,
#   'pod': 'n',
#   'pop': 90,
#   'precip': 7.4375,
#   'pres': 905,
#   'rh': 97,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.4,
#   'timestamp_local': '2021-06-19T05:00:00',
#   'timestamp_utc': '2021-06-19T03:00:00',
#   'ts': 1624071600,
#   'uv': 0,
#   'vis': 1.0125,
#   'weather': {'code': 502, 'description': 'Heavy rain', 'icon': 'r03n'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 7.69922,
#   'wind_spd': 4.79758},
#  {'app_temp': 11.7,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:06',
#   'dewpt': 9.4,
#   'dhi': 55.21,
#   'dni': 534.26,
#   'ghi': 158.47,
#   'ozone': 342.75,
#   'pod': 'd',
#   'pop': 40,
#   'precip': 0.6875,
#   'pres': 908,
#   'rh': 86,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 30.1093,
#   'temp': 11.7,
#   'timestamp_local': '2021-06-19T08:00:00',
#   'timestamp_utc': '2021-06-19T06:00:00',
#   'ts': 1624082400,
#   'uv': 0.472565,
#   'vis': 5.4,
#   'weather': {'code': 301, 'description': 'Drizzle', 'icon': 'd02d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 199,
#   'wind_gust_spd': 5.59766,
#   'wind_spd': 2.69708},
#  {'app_temp': 11.4,
#   'clouds': 100,
#   'clouds_hi': 14,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:09',
#   'dewpt': 10.3,
#   'dhi': 103.26,
#   'dni': 867.79,
#   'ghi': 715.12,
#   'ozone': 350.75,
#   'pod': 'd',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 907.5,
#   'rh': 93,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 71.512,
#   'temp': 11.4,
#   'timestamp_local': '2021-06-19T11:00:00',
#   'timestamp_utc': '2021-06-19T09:00:00',
#   'ts': 1624093200,
#   'uv': 1.65327,
#   'vis': 0.869,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 139,
#   'wind_gust_spd': 4.59766,
#   'wind_spd': 2.73987},
#  {'app_temp': 15.1,
#   'clouds': 92,
#   'clouds_hi': 8,
#   'clouds_low': 92,
#   'clouds_mid': 32,
#   'datetime': '2021-06-19:12',
#   'dewpt': 10,
#   'dhi': 117.56,
#   'dni': 937.42,
#   'ghi': 1002.62,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.0625,
#   'pres': 907.5,
#   'rh': 72,
#   'slp': 1014,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 434.972,
#   'temp': 15.1,
#   'timestamp_local': '2021-06-19T14:00:00',
#   'timestamp_utc': '2021-06-19T12:00:00',
#   'ts': 1624104000,
#   'uv': 3.7363,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 162,
#   'wind_gust_spd': 3.10547,
#   'wind_spd': 2.37379},
#  {'app_temp': 18,
#   'clouds': 69,
#   'clouds_hi': 55,
#   'clouds_low': 40,
#   'clouds_mid': 56,
#   'datetime': '2021-06-19:15',
#   'dewpt': 9.3,
#   'dhi': 108.05,
#   'dni': 892.29,
#   'ghi': 803.85,
#   'ozone': 352.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 56,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 633.115,
#   'temp': 18,
#   'timestamp_local': '2021-06-19T17:00:00',
#   'timestamp_utc': '2021-06-19T15:00:00',
#   'ts': 1624114800,
#   'uv': 3.45731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 3.32227,
#   'wind_spd': 2.62303},
#  {'app_temp': 18.1,
#   'clouds': 10,
#   'clouds_hi': 10,
#   'clouds_low': 1,
#   'clouds_mid': 6,
#   'datetime': '2021-06-19:18',
#   'dewpt': 8.7,
#   'dhi': 69.05,
#   'dni': 649.88,
#   'ghi': 266.18,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 54,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 266.103,
#   'temp': 18.1,
#   'timestamp_local': '2021-06-19T20:00:00',
#   'timestamp_utc': '2021-06-19T18:00:00',
#   'ts': 1624125600,
#   'uv': 1.657,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 3.30078,
#   'wind_spd': 2.27588},
#  {'app_temp': 14,
#   'clouds': 100,
#   'clouds_hi': 21,
#   'clouds_low': 3,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:21',
#   'dewpt': 9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 347.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 72,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14,
#   'timestamp_local': '2021-06-19T23:00:00',
#   'timestamp_utc': '2021-06-19T21:00:00',
#   'ts': 1624136400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 1.125,
#   'wind_spd': 0.953986},
#  {'app_temp': 12.7,
#   'clouds': 64,
#   'clouds_hi': 64,
#   'clouds_low': 2,
#   'clouds_mid': 5,
#   'datetime': '2021-06-20:00',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 348.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 79,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12.7,
#   'timestamp_local': '2021-06-20T02:00:00',
#   'timestamp_utc': '2021-06-20T00:00:00',
#   'ts': 1624147200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 343,
#   'wind_gust_spd': 0.899902,
#   'wind_spd': 0.956497},
#  {'app_temp': 11.6,
#   'clouds': 72,
#   'clouds_hi': 0,
#   'clouds_low': 2,
#   'clouds_mid': 72,
#   'datetime': '2021-06-20:03',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 350.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.3125,
#   'pres': 908.5,
#   'rh': 85,
#   'slp': 1015.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 11.6,
#   'timestamp_local': '2021-06-20T05:00:00',
#   'timestamp_utc': '2021-06-20T03:00:00',
#   'ts': 1624158000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 6,
#   'wind_gust_spd': 1.10254,
#   'wind_spd': 1.19666},
#  {'app_temp': 13,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 22,
#   'clouds_mid': 88,
#   'datetime': '2021-06-20:06',
#   'dewpt': 10.2,
#   'dhi': 55.12,
#   'dni': 533.43,
#   'ghi': 157.9,
#   'ozone': 352,
#   'pod': 'd',
#   'pop': 50,
#   'precip': 1.0625,
#   'pres': 908,
#   'rh': 83,
#   'slp': 1014.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 73.4744,
#   'temp': 13,
#   'timestamp_local': '2021-06-20T08:00:00',
#   'timestamp_utc': '2021-06-20T06:00:00',
#   'ts': 1624168800,
#   'uv': 0.586461,
#   'vis': 12.568,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 348,
#   'wind_gust_spd': 0.911621,
#   'wind_spd': 0.800612}]

# %%
len(results['data'])
# Out:
# 40
